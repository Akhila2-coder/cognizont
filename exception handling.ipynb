# %%
name = ["Akhila","susmitha","sindhu","shirisha"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# Akhila
# susmitha
# sindhu
# shirisha

# %%
marks=[22,34,45,56,66]
it=iter(marks)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 22
# 34
# 45
# 56
# 66

# %%
def numbers():
    yield 1
    yield 2
    yield 3
gen = numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3

# %%
file = open("demo.txt","w")
file.write("Hello student")
file.close()

# %%
file =open("demo.txt","r")       
content =file.read()
print(content)
file.close()
# Out:
# Hello student

# %%
list=[1,2,3,4]
print(list[2])
# Out:
# 3

# %%
try:
    num=10
    print(num/0)
except ZeroDivisionError:
    print("cannot divide by zero")
# Out:
# cannot divide by zero

# %%
try:
    file=open("xyz.txt","r")
except FileNotFoundError:
    print("file Doesn't exist")
# Out:
# file Doesn't exist

# %%
try:
    age=input("enter the age:")
except IntegerError:
    print("it is not a integer")
# Out:
# enter the age: 33

# %%
try:
    age=int(input("Enter the age"))
except valueError:
    print("Enter vaild age or around age")
# Out:
# Enter the age 66

# %%
try:
    num=int(input("Enter the Number:"))
    print(10/num)
    print("you entered the integer")
except ValueError:
    print("Enter the characters:")
except ZeroDivisionError:
    print("Enter number not Zero")
